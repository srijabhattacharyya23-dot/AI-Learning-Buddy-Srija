# %%
# !pip install -q streamlit pyngrok google-generativeai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 90.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 91.0 MB/s eta 0:00:00

# %%
# %%writefile app.py
import streamlit as st
import google.generativeai as genai
# Configure Gemini API
genai.configure(api_key="AQ.Ab8RN6I_uELTu3tU-jw0HOXB6VvR2Rds0Itr8QW22DiH-mXgHg")
model = genai.GenerativeModel("gemini-2.5-flash")
st.set_page_config(page_title="AI Learning Buddy Srija", page_icon="🎓")
st.title("🎓 AI Learning Buddy Srija")
topic = st.text_input("Enter a Topic")
option = st.selectbox(
"Choose Activity",
[
"Explain Concept",
"Real-Life Example",
"Generate Quiz",
"Ask Anything"
]
)
if st.button("Generate"):
if topic == "":
st.warning("Please enter a topic.")
else:
if option == "Explain Concept":
prompt = f"Explain {topic} in simple language for a beginner."
elif option == "Real-Life Example":
prompt = f"Give one simple real-life example of {topic}."
elif option == "Generate Quiz":
prompt = f"Create 5 MCQs on {topic} with answers."
else:
prompt = topic
response = model.generate_content(prompt)
st.write(response.text)
# Out:
# Writing app.py

# %%
# %%writefile app.py
import streamlit as st
import google.generativeai as genai

# Configure Gemini API
genai.configure(api_key="AQ.Ab8RN6I_uELTu3tU-jw0HOXB6VvR2Rds0Itr8QW22DiH-mXgHg")
model = genai.GenerativeModel("gemini-2.5-flash")

st.set_page_config(page_title="AI Learning Buddy Srija", page_icon="🎓")
st.title("🎓 AI Learning Buddy Srija")

topic = st.text_input("Enter a Topic")
option = st.selectbox(
    "Choose Activity",
    [
        "Explain Concept",
        "Real-Life Example",
        "Generate Quiz",
        "Ask Anything"
    ]
)

if st.button("Generate"):
    if topic == "":
        st.warning("Please enter a topic.")
    else:
        if option == "Explain Concept":
            prompt = f"Explain {topic} in simple language for a beginner."
        elif option == "Real-Life Example":
            prompt = f"Give one simple real-life example of {topic}."
        elif option == "Generate Quiz":
            prompt = f"Create 5 MCQs on {topic} with answers."
        else:
            prompt = topic

        response = model.generate_content(prompt)
        st.write(response.text)
# Out:
# Overwriting app.py

# %%
# !nohup streamlit run app.py --server.port 8501 &
# Out:
# nohup: appending output to 'nohup.out'

# %%
import time
time.sleep(10)

# %%
# !cat nohup.out
# Out:
# ...
#
# 2026-07-12 15:33:12.553 Uvicorn server started on :::8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.147.88.217:8501
#
# 2026-07-12 15:34:27.790 Script compilation error
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 659, in _run_script
#     code = self._script_cache.get_bytecode(script_path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/runtime/scriptrunner/script_cache.py", line 72, in get_bytecode
#     filebody = magic.add_magic(filebody, script_path)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/runtime/scriptrunner/magic.py", line 45, in add_magic
#     tree = ast.parse(code, script_path, "exec")
# ...

# %%
from pyngrok import ngrok
ngrok.set_auth_token("3GPPjnIRuSVzjcpzGr2y9AbBUYw_3dGbNZzMraTuULACB5eJR")
public_url = ngrok.connect(8501)
print(public_url)
# Out:
# NgrokTunnel: "https://uptight-reliable-verbalize.ngrok-free.dev" -> "http://localhost:8501"

# %%
# !fuser -k 8501/tcp
# Out:
# 8501/tcp:              812

# %%
# %%writefile app.py
import streamlit as st
import google.generativeai as genai

# Configure Gemini API
genai.configure(api_key="AQ.Ab8RN6I_uELTu3tU-jw0HOXB6VvR2Rds0Itr8QW22DiH-mXgHg")
model = genai.GenerativeModel("gemini-2.5-flash")

st.set_page_config(page_title="AI Learning Buddy Srija", page_icon="🎓")
st.title("🎓 AI Learning Buddy Srija")

topic = st.text_input("Enter a Topic")
option = st.selectbox(
    "Choose Activity",
    [
        "Explain Concept",
        "Real-Life Example",
        "Generate Quiz",
        "Ask Anything"
    ]
)

if st.button("Generate"):
    if topic == "":
        st.warning("Please enter a topic.")
    else:
        if option == "Explain Concept":
            prompt = f"Explain {topic} in simple language for a beginner."
        elif option == "Real-Life Example":
            prompt = f"Give one simple real-life example of {topic}."
        elif option == "Generate Quiz":
            prompt = f"Create 5 MCQs on {topic} with answers."
        else:
            prompt = topic

        response = model.generate_content(prompt)
        st.write(response.text)
# Out:
# Overwriting app.py

# %%
# !nohup streamlit run app.py --server.port 8501 &
# Out:
# nohup: appending output to 'nohup.out'

# %%
import time
time.sleep(10) # Give Streamlit time to start
# Out:
# WARNING:pyngrok.process.ngrok:t=2026-07-12T15:38:16+0000 lvl=warn msg="failed to open private leg" id=1f49efbda714 privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"
# WARNING:pyngrok.process.ngrok:t=2026-07-12T15:38:16+0000 lvl=warn msg="failed to open private leg" id=8048b7a09867 privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"

# %%
from pyngrok import ngrok
public_url = ngrok.connect(8501)
print(public_url)
# Out:
# NgrokTunnel: "https://uptight-reliable-verbalize.ngrok-free.dev" -> "http://localhost:8501"

# %%
# !nohup streamlit run app.py --server.port 8501 &
# Out:
# nohup: appending output to 'nohup.out'

# %%
import time
time.sleep(10)

# %%
# !cat nohup.out
# Out:
# ...
#
# 2026-07-12 15:33:12.553 Uvicorn server started on :::8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.147.88.217:8501

# %%
# !pip install -q pyngrok

# %%
from pyngrok import ngrok
ngrok.set_auth_token("3GPPjnIRuSVzjcpzGr2y9AbBUYw_3dGbNZzMraTuULACB5eJR")
public_url = ngrok.connect(8501)
print(public_url)
# Out:
# NgrokTunnel: "https://uptight-reliable-verbalize.ngrok-free.dev" -> "http://localhost:8501"
